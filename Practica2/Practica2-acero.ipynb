# %% [markdown]
# # Práctica 2 – Estática. Registro de distancia y posición
# Por Luna Kadysz y Kenneth Syddall

# %% [markdown]
# Link a la página de la materia:
# https://materias.df.uba.ar/l4a2021c1/practica-11-estatica-registro-de-distancia-y-posicion/

# %% [markdown]
# ## Actividad 2.1
# ### Determinación del módulo de Young
#
# Calcular cuánto se desplaza EL EXTREMO libre de la barra:
# ![20210415-183340.png](attachment:488bcba8-22b4-4619-a878-a06a8fcea976.png)
#
# Datos:
#
# E ≅ 10×1010 N/m2
#
# L = 40 cm
#
# d = 5 mm
#
# m = 0.01 kg
#
# Forma de entrega: Sin entrega. Estimar estas dos cantidades y dejar asentado el desarrollo de forma más o menos prolija en el “cuaderno de laboratorio”, sea el fomato que éste último tenga.

# %% [markdown]
# ## Actividad 2.2
# ### Sensores de distancia – longitud:
# Elegir la tarea de medición mencionadas en la lista, según su número de grupo (Grupo 14 vuelvea la tarea 1). Para esta tarea, elegir un sistema de medición o sensor para realizarla y justifiquen(puede ser otro sensor que no hayamos mencionado en la clase eh!)
#
# 1.Distancia de la superficie de la tierra a una nube o capa de aerosoles atmosféricos
#
# 2.Dimensiones edilicias de una fábrica
#
# 3.Control del diámetro de agujeros de arandelas en una línea de producción.
#
# 4.Deformación por dilatación térmica del bloque del motor de un automóvil.
#
# 5.Distancia de la Tierra a la Luna.
#
# 6.Control de posición del cabezal de una impresora tipo plotter.
#
# 7.Distancia entre un automóvil y un obstáculo para maniobra de estacionamiento.
#
# 8.Diámetro de una broca de perforación (mecha) de taladro.
#
# 9.Distancia entre vehículos en movimiento para sistemas de conducción autónoma.
#
# 10.Diámetro de un cabello humano.
#
#
# 11.Distancia entre pupilas oculares humanas para fabricación de anteojos.
#
# 12.Mediciones antropométricas para reconocimiento facial.
#
# 13.Medición para realimentación de un sistema de actuadores para control de vuelo o de unbrazo robot.Reportar el intervalo de
# valores de distancias típicas para esa tarea y las precisiones requeridaspara dichas mediciones.
#
# Justificar la elección del sistema de medición. Considerar tanto los rangos y precisiones del siste-ma de medición elegido como los aspectos metodológicos o procedimentales necesarios para rea-lizar la tarea.Buscar un equipo comercial o experimental que sea capaz de realizar la medición. Incluir cita olink al artículo u hoja de datos consultado. Reportar las especificaciones del instrumento o experi-mento que considere útiles para justificar la elección.Forma de entrega: Para la fecha definida en el cronograma, deberán armar una pre-sentación mínima (una, dos o a lo sumo tres diapositivas) describiendo las caracte-rísticas de la tarea a realizar, el sensor o instrumento elegido y una justificación paraello, basados en alguna especificación del mismo.

# %% [markdown]
# ## Respuesta
#
# Existen muchos metodo que pueden dar una distancia media aceptable de nuestro satelite natural. Uno sencillo podria ser (http://19e37.com/blog/como-supimos-la-distancia-tierra-luna/).
# Pero en nuestro caso vamos a mostrar como se mide actualmente la distancia a la luna a travez del Observatorio de la Costa Azul (OCA). El observatorio de la Côte d'Azur está instalado en cuatro sitios: la meseta de Calern, el monte Gros donde se encuentra la sede (sitio histórico del Observatorio de la Côte d'Azur), el campus de Valrose en Niza y El sitio de Géoazur en el tecnopolo Sophia Antipolis.
# Nuestra intención no esdar una descripción completa del funcionamiento de este observatorio para medir la distancia a la luna, sino mas bien una descripcion general del metodo y los equipos que se utilizan en este proceso. Toda la información fue obtenida de las siguientes fuentes:
# * https://tmurphy.physics.ucsd.edu/papers/PASP_120_20.pdf
# * https://aas.aanda.org/articles/aas/pdf/1998/11/ds1427.pdf
#
# Para esto vamos a dividir la explicación en tres partes:
# * Metodo LLR
# * Laser y telescopio
# * Reflector
# * Detector

# %% [markdown]
# ## Actividad 2.3
# ### Medición indirecta del tamaño de una rendija:
#
# Conociendo cuánto se deforma el extremo de la barra (lo calcularon en la actividad anterior), y suponiendo que la rendija variable está ubicada en ese extremo de la barra, estimar la distancia necesaria a la  pantalla  para  estar  en  condición  de Fraunhoffer, y cuál sería la distancia entre franjas (o, más correcto, entre los mínimos de intensidad):
# ![20210415-184553.png](attachment:f2c2e759-68cf-4ead-8f93-023f65e0bb16.png)
# En la condición de Fraunhöffer, el patrón de interferencia está dado por
# ![20210415-184610.png](attachment:a7f3aa47-60d9-4ebc-991f-de3ec8441da1.png)
# donde a es el tamaño de la rendija, D la distancia a la pantalla, z la coordenada sobre la pantalla y
# $\lambda$ la longitud de onda de la fuente de luz utilizada.
#
# Forma de entrega: Sin entrega. Estimar estas dos cantidades y dejar asentado el desarrollo de forma más o menos prolija en el “cuaderno de laboratorio”, sea el fomato que éste último tenga.

# %% [markdown]
# ### VER QUE TODOS TENGAN ELMISMO LARGO DE PIXELES PARA PODER COMPARAR

# %%
import matplotlib
matplotlib.use('TkAgg')
#matplotlib.use('Qt5Agg')
import imageio
import matplotlib.pyplot as plt
from scipy import ndimage
from scipy import signal
import numpy as np

# %%
import os
frames = []
colors = ['Red','Green','Blue']
images_dict = {os.path.splitext(k)[0]: {} for k in os.listdir('Datos/datos_acero') if os.path.splitext(k)[1] == '.jpg'}

#guardo todos los rgb por imagen de la carpeta
for i,file in enumerate(os.listdir('Datos/datos_acero')):
    ext = os.path.splitext(file)[1] #agarro la extension del archivo
    if ext == '.jpg':
        img = imageio.imread(f'Datos/datos_acero/{file}')
        images_dict[os.path.splitext(file)[0]] = {k: np.array(img[:,:,i])  for i,k in enumerate(colors)}

# %%
images_dict.keys()
# Out:
# dict_keys(['papela', 'a3', 'a5', 'a0', 'a2', 'a1', 'a4', 'a00'])

# %% [markdown]
# ### DATO ROJO  1

# %%
#probamos con rojo 

# %matplotlib inline

color = 'Red'
A = images_dict['a00'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')
# Out:
# Text(0, 0.5, 'Pixeles[px]')

# %%
R = ndimage.rotate(A, 2.6)[1550:2100,1335:1355]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(20):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
def promedio(R):
    mediana = []
    error = []
    for i in range(len(R)):
        mediana.append(np.mean(R[i]))
        error.append(np.std(R[i]))
    return mediana, error 

ceros = []
err_cr=[]

# %matplotlib inline

mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
#puntos_x = np.array(plt.ginput(9))
#puntos_x

# %%
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 80)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

p=[peaks[1]-peaks[0], peaks[4]-peaks[3]]

z0 = np.mean(p)
errz0 = np.std(p)
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
#plt.axis([0, 160, -1.1, 1.1])
# Out:
# [ 37 161 303 396 508]
# La diferencia media entre minimos es: 118.0 +- 6.0

# %% [markdown]
# ### DATO ROJO  2

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a0'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 2.5)[1550:2100,1326:1356]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(30):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 40)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

pea=[]
for i in range(len(peaks)):
    if i != 4 and i != 5:
        pea.append(peaks[i])
print(pea)
pdiff = np.diff(pea)
p=[]
for i in range(len(pdiff)):
    if i != 3:
        p.append(pdiff[i])

print(p)
ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
# Out:
# [ 18  58 122 196 238 308 353 427 487 532]
# [18, 58, 122, 196, 353, 427, 487, 532]
# [40, 64, 74, 74, 60, 45]
# La diferencia media entre minimos es: 59.5 +- 13.111699610144623

# %% [markdown]
# ### DATO ROJO  3

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a1'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 2.5)[1400:2250,1333:1363]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(30):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 40)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

pea=[]
for i in range(len(peaks)):
    if i != 9:
        pea.append(peaks[i])
print(pea)
pdiff = np.diff(pea)
print(pdiff)
p=[]
for i in range(len(pdiff)):
    if i != 8:
        p.append(pdiff[i])
print(p)

ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
# Out:
# [  2  72 120 168 208 255 303 346 387 444 488 536 581 627 681 725 770 812]
# [2, 72, 120, 168, 208, 255, 303, 346, 387, 488, 536, 581, 627, 681, 725, 770, 812]
# [ 70  48  48  40  47  48  43  41 101  48  45  46  54  44  45  42]
# [70, 48, 48, 40, 47, 48, 43, 41, 48, 45, 46, 54, 44, 45, 42]
# La diferencia media entre minimos es: 47.266666666666666 +- 6.951898221988645

# %% [markdown]
# ### DATO ROJO  4

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a2'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 2.5)[1400:2200,1333:1363]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(30):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 20)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

p = np.diff(peaks)
print(p)
ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
# Out:
# [  5  27  55  86 125 162 191 232 265 300 329 367 399 429 460 493 513 548
#  587 617 652 691 725 765 793]
# [22 28 31 39 37 29 41 33 35 29 38 32 30 31 33 20 35 39 30 35 39 34 40 28]
# La diferencia media entre minimos es: 32.833333333333336 +- 5.296749527356901

# %% [markdown]
# ### DATO ROJO  5

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a3'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 2.5)[1420:2180,1335:1365]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(30):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 18)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

p = np.diff(peaks)
print(p)
ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
# Out:
# [  1  39  71  95 124 147 170 201 229 253 284 308 336 361 403 427 469 491
#  509 545 567 589 619 642 675 693 715 735 756]
# [38 32 24 29 23 23 31 28 24 31 24 28 25 42 24 42 22 18 36 22 22 30 23 33
#  18 22 20 21]
# La diferencia media entre minimos es: 26.964285714285715 +- 6.53278622934865

# %% [markdown]
# ### DATO ROJO  6

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a4'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 2.5)[1420:2180,1340:1357]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(1357-1340):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 15)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

p = np.diff(peaks)
print(p)
ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
# Out:
# [  5  37  64  85 105 124 147 170 189 218 238 260 283 302 321 343 367 395
#  414 431 453 468 500 521 540 561 584 600 625 649 675 696 719 745]
# [32 27 21 20 19 23 23 19 29 20 22 23 19 19 22 24 28 19 17 22 15 32 21 19
#  21 23 16 25 24 26 21 23 26]
# La diferencia media entre minimos es: 22.424242424242426 +- 4.0228913394608705

# %% [markdown]
# ### DATO ROJO  7

# %%
# %matplotlib inline

color = 'Red'
A = images_dict['a5'][color]
plt.figure(figsize = (9, 7.5))
plt.imshow(A, cmap=plt.cm.Reds_r)
plt.title(f'{color} channel image in {color}')
plt.xlabel('Pixeles [px]')
plt.ylabel('Pixeles[px]')

R = ndimage.rotate(A, 3)[1400:2200,1355:1370]
Rt = np.transpose(R)
plt.imshow(Rt, cmap=plt.cm.Reds_r)
plt.imshow(R, cmap=plt.cm.Reds_r)

# %%
plt.figure(figsize = (10, 7))
for i in range(15):
    plt.plot(range(len(Rt[i])),Rt[i])

# %%
mediana, error = promedio(R)
plt.plot(range(len(mediana)),np.array(mediana))

# %%
y = - np.array(mediana)

# %%
# %matplotlib inline
from scipy.signal import find_peaks
plt.figure()
peaks, _ = find_peaks(y,distance= 15)
plt.plot(range(len(y)),y)
plt.plot(peaks, y[peaks], "o")
print(peaks)

p = np.diff(peaks)
print(p)
ceros.append(np.mean(p))
err_cr.append(np.std(p))
print(f'La diferencia media entre minimos es: {np.mean(p)} +- {np.std(p)}')
#plt.axis([0, 160, -1.1, 1.1])
# Out:
# [  6  26  43  71  89 108 123 140 155 172 190 208 226 248 265 294 310 329
#  348 368 391 411 428 457 476 492 513 551 593 615 633 650 666 692 708 733
#  754 772 793]
# [20 17 28 18 19 15 17 15 17 18 18 18 22 17 29 16 19 19 20 23 20 17 29 19
#  16 21 38 42 22 18 17 16 26 16 25 21 18 21]
# La diferencia media entre minimos es: 20.710526315789473 +- 5.830536197861277

# %%
print(ceros)
# Out:
# [59.5, 47.266666666666666, 32.833333333333336, 26.964285714285715, 22.424242424242426, 20.710526315789473]

# %%
g=9.821 #m/s^2
L=30.9 /100 #cm-->m
d=4.0 /1000 #mm-->m
D=189 /100 #cm-->m
lam= 670.8e-9 #nm-->m
x= 25.9 /100 #cm-->m
m0=18 #g
M=[3.0912,4.8188,6.9318,9.0212,11.0755,13.6564]#g

E0=32*g*((L*x**2)-((x**3)/3))/(np.pi*d**4*D*lam*5309)
E=[]
m=[]

# %%
for i in range(5):
    Ei= ((M[i]+18)/1000)/((1/ceros[i])-(1/z0))
    m.append((M[i]+18)/1000)
    E.append(E0*Ei)

# %%
plt.plot(m,E)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
beta=[]
for i in range(5):
    b=((1/ceros[i])-(1/z0))
    beta.append(b)

errbeta=[]
for i in range(5):
    erri=np.sqrt((err_cr[i]/(ceros[i]**2))**2+(errz0/(z0**2))**2)
    errbeta.append(erri)

# %%
# %matplotlib qt
plt.figure(figsize = (10, 7))
param=np.polyfit(m,beta,1)
mod=np.polyval(param,m)
plt.plot(m,mod,'-')
plt.plot(m,beta,'.')
plt.errorbar(m, beta, yerr=errbeta, fmt='.', label='datos')
plt.xlabel(r'$m (g)$',fontsize=16)
plt.ylabel(r'$\beta$',fontsize=16)
plt.show()

print('A*x+B')
print('A:',param[0] , '   B:',param[1])
# Out:
# A*x+B
# A: 3.5505404898742987    B: -0.06717425260523335

# %%
E=E0/param[0]
print(E)
# Out:
# 244235356381.82385

# %%
## Error E0
eL=0.5 /100 #cm-->m
ed=0.2 /1000 #mm-->m
eD=0.5 /100 #cm-->m
elam= 632.8e-9 #nm-->m
ex= 0.5 /100 #cm-->m
c=14565
ec=775

E0=32*g*((L*x**2)-((x**3)/3))/(np.pi*d**4*D*lam*c)

e1=(32*g*(x**2)/(np.pi*d**4*D*lam*c))**2 * eL**2
e2=(32*g*((L*2*x)-(x**2))/(np.pi*d**4*D*lam*c))**2 * ex**2
e3=(32*4*g*((L*x**2)-((x**3)/3))/(np.pi*d**5*D*lam*c))**2 * ed**2
e4=(32*g*((L*x**2)-((x**3)/3))/(np.pi*d**4*D**2*lam*c))**2 * eD**2
e5=(32*g*((L*x**2)-((x**3)/3))/(np.pi*d**4*D*lam*c**2))**2 * ec**2

eE0= np.sqrt(e1+e2+e3+e4+e5)
print (np.sqrt(e1),np.sqrt(e2),np.sqrt(e3),np.sqrt(e4),np.sqrt(e5))
print(eE0)

eE= np.sqrt((eE0/param[0])**2 + (E0*param[1]/(param[0]**2))**2)
# Out:
# 7097739187.527397 9838179028.271564 63217197030.244026 836206309.9238626 16818856058.509823
# 66536868190.77682

# %%
print('El valor del modulo de young es(', E*1e-9 ,'+-', eE*1e-9,') * 1*10^9')
# Out:
# El valor del modulo de young es( 244.23535638182386 +- 18.81546469520576 ) * 1*10^9
